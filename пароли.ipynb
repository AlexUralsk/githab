# %%
import random as rnd
def cifra(c):    # проверка числа
    if c.isdigit() and int(c) > 0:
        return int(c)
    else:
        return False
def bukva(c):    # проверка на да или нет
    if c.lower() == 'да':        
        return c
    elif c.lower() == 'нет':
         return c
    else:
        c = False
        return c
def net_a(c):     # проверка на отсутствие элементов строки 'a'
    for i in a:
        if i in c:
            c.replace(i, '')
            return c
        
digits = '0123456789'
lowercase_letters = 'abcdefghijklmnopqrstuvwxyz'
uppercase_letters = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
punctuation = '!#$%&*+-=?@^_'
chars = ''

#______________________________________________
print('Сколько паролей сгенерировать?')
n =  cifra(input())
while n == False:
    print('введите положительное, целое число')    
    n =  cifra(input())
print(n)                    # количество паролей
#______________________________________________
print('какая должна быть длина пароля?')
m =cifra(input())
while m == False:
    print('введите положительное, целое число')    
    m =  cifra(input())

print(m)                    #  количество символов в пароле
#______________________________________________
print('Включать ли цифры 0123456789?')
z = bukva(input())
while z == False:
    print('введите: да или нет')
    z = bukva(input())
if z == 'да':
    z = digits
else:
    z = ''
print ('z =', z)            
#______________________________________________
print('Включать ли прописные буквы ABCDEFGHIJKLMNOPQRSTUVWXYZ?')
x = bukva(input())
while x == False:
    print('введите: да или нет')
    x = bukva(input())
if x == 'да':
    x = uppercase_letters
else:
    x = ''
print ('x=', x)
#______________________________________________
print('Включать ли строчные буквы abcdefghijklmnopqrstuvwxyz??')
v = bukva(input())
while v == False:
    print('введите: да или нет')
    v = bukva(input())
if v == 'да':
    v = lowercase_letters
else:
    v = ''
print ('v=', v)
#______________________________________________
print('Включать ли символы !#$%&*+-=?@^_?')    
b = bukva(input())
while b == False:
    print('введите: да или нет')
    b = bukva(input())
if b == 'да':
    b = punctuation
else:
    b = ''
print ('b=', b)
#______________________________________________
print('Исключать ли неоднозначные символы il1Lo0O?')

a = bukva(input())
while a == False:
    print('введите: да или нет')
    a = bukva(input())
if a == 'да':
    a = 'il1Lo0O'
else:
    a = ''
print('a=', a)
#______________________________________________
i = 0
j = 0
while i < n + 1:
    chars = ''
    d = 0
    while j <= m:
        if z != '':     
            z = net_a(z)       
            chars +=  rnd.choice(z)
            d +=1
        if d < m:
            if x != '':
                x = net_a(x)
                chars +=  rnd.choice(x)
                d +=1
        if d < m:
            if v != '':
                v= net_a(v)
                chars +=  rnd.choice(v) 
                d +=1                    
        if d < m:
            if b != '':
                chars +=  rnd.choice(b) 
                d +=1        
        j += 1 
        if d == m:
            print(chars)    
    i += 1
# Out:
# Сколько паролей сгенерировать?
# введите положительное, целое число
# введите положительное, целое число
# введите положительное, целое число
# 2
# какая должна быть длина пароля?
# 8
# Включать ли цифры 0123456789?
# введите: да или нет
# z = 0123456789
# Включать ли прописные буквы ABCDEFGHIJKLMNOPQRSTUVWXYZ?
# x= ABCDEFGHIJKLMNOPQRSTUVWXYZ
# Включать ли строчные буквы abcdefghijklmnopqrstuvwxyz??
# v= abcdefghijklmnopqrstuvwxyz
# Включать ли символы !#$%&*+-=?@^_?
# b= !#$%&*+-=?@^_
# Исключать ли неоднозначные символы il1Lo0O?
# введите: да или нет
# a= il1Lo0O
# 0Wt?5Wj%
