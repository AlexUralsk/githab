# %% [markdown]
# Упаковка дубликатов 🌶️
# На вход программе подается строка текста, содержащая символы. Напишите программу, которая упаковывает последовательности одинаковых символов заданной строки в подсписки.
#
# Формат входных данных
# На вход программе подается строка текста, содержащая символы, отделенные символом пробела.
#
# Формат выходных данных
# Программа должна вывести указанный вложенный список.
#
# Тестовые данные 🟢
# Номер теста	Входные данные	Выходные данные
# 1	a b c d	[['a'], ['b'], ['c'], ['d']]
# 2	w w w o r l d g g g g r e a t t e c c h e m g g p w w	[['w', 'w', 'w'], ['o'], ['r'], ['l'], ['d'], ['g', 'g', 'g', 'g'], ['r'], ['e'], ['a'], ['t', 't'], ['e'], ['c', 'c'], ['h'], ['e'], ['m'], ['g', 'g'], ['p'], ['w', 'w']]
# 3	g i v e t h h i i s m a a a n a g u u n	[['g'], ['i'], ['v'], ['e'], ['t'], ['h', 'h'], ['i', 'i'], ['s'], ['m'], ['a', 'a', 'a'], ['n'], ['a'], ['g'], ['u', 'u'], ['n']]
# 4	w w w w w w w w w w w w y y y t r t r r t r t r t w w w w w w w w	[['w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w'], ['y', 'y', 'y'], ['t'], ['r'], ['t'], ['r', 'r'], ['t'], ['r'], ['t'], ['r'], ['t'], ['w', 'w', 'w', 'w', 'w', 'w', 'w', 'w']]
# 5	w w w w w w w w w w w w w w w w w w w w	[['w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w', 'w']]
# 6	0 0 1 2 3 4 4 5 6 6 6 7 8 9 4 4	[['0', '0'], ['1'], ['2'], ['3'], ['4', '4'], ['5'], ['6', '6', '6'], ['7'], ['8'], ['9'], ['4', '4']]
# 7	5 1 1 g w 6 6 1 8 h e e o 5 t t 2	[['5'], ['1', '1'], ['g'], ['w'], ['6', '6'], ['1'], ['8'], ['h'], ['e', 'e'], ['o'], ['5'], ['t', 't'], ['2']]
# 8	r a t a t a t a t a ! ! ?	[['r'], ['a'], ['t'], ['a'], ['t'], ['a'], ['t'], ['a'], ['t'], ['a'], ['!', '!'], ['?']]
